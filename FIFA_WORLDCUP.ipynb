# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# %%
df_match=pd.read_csv("WorldCupMatches.csv")
df_player=pd.read_csv("WorldCupPlayers.csv")
df_wc=pd.read_csv("WorldCups.csv")

# %% [markdown]
# # Match Dataset

# %%
df_match.head()
# Out:
#      Year              Datetime    Stage         Stadium         City  \
# 0  1930.0  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1  1930.0  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 2  1930.0  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 3  1930.0  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4  1930.0  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 0         France              4.0              1.0         Mexico
# 1            USA              3.0              0.0        Belgium
# 2     Yugoslavia              2.0              1.0         Brazil
# 3        Romania              3.0              1.0           Peru
# 4      Argentina              1.0              0.0         France
#
#   Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 0                     4444.0                   3.0                   0.0
# ...

# %%
df_match.isnull().sum()
# Out:
# Year                    3720
# Datetime                3720
# Stage                   3720
# Stadium                 3720
# City                    3720
# Home Team Name          3720
# Home Team Goals         3720
# Away Team Goals         3720
# Away Team Name          3720
# Win conditions          3720
# Attendance              3722
# Half-time Home Goals    3720
# Half-time Away Goals    3720
# Referee                 3720
# Assistant 1             3720
# Assistant 2             3720
# RoundID                 3720
# MatchID                 3720
# Home Team Initials      3720
# Away Team Initials      3720
# dtype: int64

# %%
df_match.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4572 entries, 0 to 4571
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Year                  852 non-null    float64
#  1   Datetime              852 non-null    object
#  2   Stage                 852 non-null    object
#  3   Stadium               852 non-null    object
#  4   City                  852 non-null    object
#  5   Home Team Name        852 non-null    object
#  6   Home Team Goals       852 non-null    float64
#  7   Away Team Goals       852 non-null    float64
#  8   Away Team Name        852 non-null    object
#  9   Win conditions        852 non-null    object
#  10  Attendance            850 non-null    float64
#  11  Half-time Home Goals  852 non-null    float64
#  12  Half-time Away Goals  852 non-null    float64
#  13  Referee               852 non-null    object
# ...

# %%
df_match.drop_duplicates()
# Out:
#        Year              Datetime        Stage             Stadium  \
# 0    1930.0  13 Jul 1930 - 15:00       Group 1             Pocitos
# 1    1930.0  13 Jul 1930 - 15:00       Group 4      Parque Central
# 2    1930.0  14 Jul 1930 - 12:45       Group 2      Parque Central
# 3    1930.0  14 Jul 1930 - 14:50       Group 3             Pocitos
# 4    1930.0  15 Jul 1930 - 16:00       Group 1      Parque Central
# ..      ...                   ...          ...                 ...
# 832  2014.0  29 Jun 2014 - 13:00   Round of 16    Estadio Castelao
# 833  2014.0  29 Jun 2014 - 17:00   Round of 16    Arena Pernambuco
# 834  2014.0  01 Jul 2014 - 13:00   Round of 16  Arena de Sao Paulo
# 835  2014.0  01 Jul 2014 - 17:00   Round of 16    Arena Fonte Nova
# 852     NaN                   NaN          NaN                 NaN
#
#             City Home Team Name  Home Team Goals  Away Team Goals  \
# 0    Montevideo          France              4.0              1.0
# ...

# %%
# Missing values are start from the 852 so we are drop all the missimg values
df_match.drop(range(852,4572), inplace=True)

# %%
df_match.shape
# Out:
# (852, 20)

# %%
df_match["Attendance"].sort_values(ascending=True)
# Out:
# 9        2000.0
# 3        2549.0
# 127      2823.0
# 27       3000.0
# 67       3580.0
#          ...
# 63     142429.0
# 71     152772.0
# 74     173850.0
# 823         NaN
# 841         NaN
# Name: Attendance, Length: 852, dtype: float64

# %%
# here 2 missimg values are there so first we find it after that we will filling that space
df_match.iloc[820:845]
# Out:
#        Year              Datetime                     Stage  \
# 820  2014.0  28 Jun 2014 - 13:00                Round of 16
# 821  2014.0  28 Jun 2014 - 17:00                Round of 16
# 822  2014.0  30 Jun 2014 - 13:00                Round of 16
# 823  2014.0  30 Jun 2014 - 17:00                Round of 16
# 824  2014.0  04 Jul 2014 - 17:00             Quarter-finals
# 825  2014.0  04 Jul 2014 - 13:00             Quarter-finals
# 826  2014.0  08 Jul 2014 - 17:00                Semi-finals
# 827  2014.0  12 Jul 2014 - 17:00   Play-off for third place
# 828  2014.0  13 Jul 2014 - 16:00                      Final
# 829  2014.0  09 Jul 2014 - 17:00                Semi-finals
# 830  2014.0  05 Jul 2014 - 17:00             Quarter-finals
# 831  2014.0  05 Jul 2014 - 13:00             Quarter-finals
# 832  2014.0  29 Jun 2014 - 13:00                Round of 16
# 833  2014.0  29 Jun 2014 - 17:00                Round of 16
# 834  2014.0  01 Jul 2014 - 13:00                Round of 16
# ...

# %%
# as we can shown that an missimg values are at 823 nd 841 place and both missing value are at the Estadio Beira-Rio
df_match[df_match.Stadium == "Estadio Beira-Rio"]
# Out:
#        Year              Datetime        Stage            Stadium  \
# 781  2014.0  15 Jun 2014 - 16:00       Group E  Estadio Beira-Rio
# 789  2014.0  18 Jun 2014 - 13:00       Group B  Estadio Beira-Rio
# 802  2014.0  22 Jun 2014 - 16:00       Group H  Estadio Beira-Rio
# 812  2014.0  25 Jun 2014 - 13:00       Group F  Estadio Beira-Rio
# 823  2014.0  30 Jun 2014 - 17:00   Round of 16  Estadio Beira-Rio
# 841  2014.0  30 Jun 2014 - 17:00   Round of 16  Estadio Beira-Rio
#
#               City  Home Team Name  Home Team Goals  Away Team Goals  \
# 781  Porto Alegre           France              3.0              0.0
# 789  Porto Alegre        Australia              2.0              3.0
# 802  Porto Alegre   Korea Republic              2.0              4.0
# 812  Porto Alegre          Nigeria              2.0              3.0
# 823  Porto Alegre          Germany              2.0              1.0
# 841  Porto Alegre          Germany              2.0              1.0
#
# ...

# %%
avg_att = df_match[df_match.Stadium == "Estadio Beira-Rio"]["Attendance"].mean()

# %%
df_match.Attendance.fillna(avg_att, inplace=True)

# %%
df_match.isna().sum()
# Out:
# Year                    0
# Datetime                0
# Stage                   0
# Stadium                 0
# City                    0
# Home Team Name          0
# Home Team Goals         0
# Away Team Goals         0
# Away Team Name          0
# Win conditions          0
# Attendance              0
# Half-time Home Goals    0
# Half-time Away Goals    0
# Referee                 0
# Assistant 1             0
# Assistant 2             0
# RoundID                 0
# MatchID                 0
# Home Team Initials      0
# Away Team Initials      0
# dtype: int64

# %%
df_player.head()
# Out:
#    RoundID  MatchID Team Initials           Coach Name Line-up  Shirt Number  \
# 0      201     1096           FRA  CAUDRON Raoul (FRA)       S             0
# 1      201     1096           MEX     LUQUE Juan (MEX)       S             0
# 2      201     1096           FRA  CAUDRON Raoul (FRA)       S             0
# 3      201     1096           MEX     LUQUE Juan (MEX)       S             0
# 4      201     1096           FRA  CAUDRON Raoul (FRA)       S             0
#
#         Player Name Position Event
# 0       Alex THEPOT       GK   NaN
# 1   Oscar BONFIGLIO       GK   NaN
# 2  Marcel LANGILLER      NaN  G40'
# 3      Juan CARRENO      NaN  G70'
# 4   Ernest LIBERATI      NaN   NaN

# %% [markdown]
# # Player Dataset

# %%
df_player.isnull().sum()
# Out:
# RoundID              0
# MatchID              0
# Team Initials        0
# Coach Name           0
# Line-up              0
# Shirt Number         0
# Player Name          0
# Position         33641
# Event            28715
# dtype: int64

# %%
df_player.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37784 entries, 0 to 37783
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   RoundID        37784 non-null  int64
#  1   MatchID        37784 non-null  int64
#  2   Team Initials  37784 non-null  object
#  3   Coach Name     37784 non-null  object
#  4   Line-up        37784 non-null  object
#  5   Shirt Number   37784 non-null  int64
#  6   Player Name    37784 non-null  object
#  7   Position       4143 non-null   object
#  8   Event          9069 non-null   object
# dtypes: int64(3), object(6)
# memory usage: 2.6+ MB

# %%
df_player.Position.value_counts()
# Out:
# Position
# GK     2441
# C      1510
# GKC     192
# Name: count, dtype: int64

# %%
df_player[df_player.Position.isna()]
# Out:
#        RoundID    MatchID Team Initials               Coach Name Line-up  \
# 2          201       1096           FRA      CAUDRON Raoul (FRA)       S
# 3          201       1096           MEX         LUQUE Juan (MEX)       S
# 4          201       1096           FRA      CAUDRON Raoul (FRA)       S
# 6          201       1096           FRA      CAUDRON Raoul (FRA)       S
# 7          201       1096           MEX         LUQUE Juan (MEX)       S
# ...        ...        ...           ...                      ...     ...
# 37779   255959  300186501           ARG  SABELLA Alejandro (ARG)       N
# 37780   255959  300186501           GER       LOEW Joachim (GER)       N
# 37781   255959  300186501           ARG  SABELLA Alejandro (ARG)       N
# 37782   255959  300186501           GER       LOEW Joachim (GER)       N
# 37783   255959  300186501           ARG  SABELLA Alejandro (ARG)       N
#
#        Shirt Number       Player Name Position       Event
# ...

# %%
df_player.shape
# Out:
# (37784, 9)

# %% [markdown]
# # Worldcup Dataset

# %% [markdown]
# df_wc.head()

# %%
df_wc.isnull().sum()
# Out:
# Year              0
# Country           0
# Winner            0
# Runners-Up        0
# Third             0
# Fourth            0
# GoalsScored       0
# QualifiedTeams    0
# MatchesPlayed     0
# Attendance        0
# dtype: int64

# %%
df_wc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Year            20 non-null     int64
#  1   Country         20 non-null     object
#  2   Winner          20 non-null     object
#  3   Runners-Up      20 non-null     object
#  4   Third           20 non-null     object
#  5   Fourth          20 non-null     object
#  6   GoalsScored     20 non-null     int64
#  7   QualifiedTeams  20 non-null     int64
#  8   MatchesPlayed   20 non-null     int64
#  9   Attendance      20 non-null     object
# dtypes: int64(4), object(6)
# memory usage: 1.7+ KB

# %%
df_wc.shape
# Out:
# (20, 10)

# %% [markdown]
# # Exploratory Data Analysis

# %%
home_goal_scored = df_match.groupby('Home Team Name')['Home Team Goals'].sum().sort_values(ascending = False).to_frame().reset_index().rename(columns={'Home Team Name':'Team'})
away_goal_scored = df_match.groupby('Away Team Name')['Away Team Goals'].sum().sort_values(ascending = False).to_frame().reset_index().rename(columns={'Away Team Name':'Team'})
goal_scored = pd.merge(home_goal_scored,away_goal_scored,on='Team',how='outer').set_index('Team').sort_values(by=['Home Team Goals','Away Team Goals'], ascending=False)

# %%
goal_scored
# Out:
#                    Home Team Goals  Away Team Goals
# Team
# Brazil                       180.0             45.0
# Argentina                    111.0             22.0
# Germany FR                    99.0             32.0
# Italy                         99.0             29.0
# Hungary                       73.0             14.0
# ...                            ...              ...
# Egypt                          NaN              3.0
# Kuwait                         NaN              2.0
# El Salvador                    NaN              1.0
# Israel                         NaN              1.0
# Dutch East Indies              NaN              0.0
#
# [83 rows x 2 columns]

# %%
goal_scored.head(30).plot(kind='barh', rot=0, figsize=(16,9))
plt.title("Goal Scored by Team")
plt.xlabel("Goal Scored")
plt.tight_layout()
plt.show()

# %%
home_win = df_match[(df_match['Home Team Goals']) > (df_match['Away Team Goals'])][['Home Team Name', 'Home Team Goals', 'Away Team Goals', 'Away Team Name']]
home_win_team = home_win['Home Team Name'].value_counts().sort_values(ascending = False).to_frame().reset_index().rename(columns={'Home Team Name':'Home Win','index':'Team'})

# %%
home_win_team.head(5)
# Out:
#      Home Win  count
# 0      Brazil     59
# 1   Argentina     41
# 2       Italy     38
# 3  Germany FR     29
# 4     Germany     24

# %%
away_win = df_match[(df_match['Home Team Goals']) < (df_match['Away Team Goals'])][['Home Team Name', 'Home Team Goals', 'Away Team Goals', 'Away Team Name']]
away_win_team = away_win['Away Team Name'].value_counts().sort_values(ascending = False).to_frame().reset_index().rename(columns={'Away Team Name':'Away Win','index':'Team'})

# %%
away_win_team.head(5)
# Out:
#       Away Win  count
# 0        Spain     13
# 1       Brazil     12
# 2  Netherlands     11
# 3      Germany     10
# 4       France     10

# %%
draw = df_match[((df_match['Home Team Goals']) == (df_match['Away Team Goals'])) & (~df_match['Win conditions'].str.contains("penalties"))][['Home Team Name', 'Home Team Goals', 'Away Team Goals', 'Away Team Name', 'Win conditions']]
draw_team1 = draw['Home Team Name'].value_counts().sort_values(ascending = False).to_frame().reset_index().rename(columns={'Home Team Name':'Draw','index':'Team'})
draw_team2 = draw['Away Team Name'].value_counts().sort_values(ascending = False).to_frame().reset_index().rename(columns={'Away Team Name':'Draw','index':'Team'})
draw_team = pd.merge(draw_team1,draw_team2,on='Team',how='outer').fillna(0)
draw_team["Draw"] = draw_team['Draw_x'] + draw_team['Draw_y']
draw_team.drop(columns=['Draw_x', 'Draw_y'], inplace=True)
draw_team['Draw'].sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_29152\1426745591.py in ?()
#       1 draw = df_match[((df_match['Home Team Goals']) == (df_match['Away Team Goals'])) & (~df_match['Win conditions'].str.contains("penalties"))][['Home Team Name', 'Home Team Goals', 'Away Team Goals', 'Away Team Name', 'Win conditions']]
#       2 draw_team1 = draw['Home Team Name'].value_counts().sort_values(ascending = False).to_frame().reset_index().rename(columns={'Home Team Name':'Draw','index':'Team'})
#       3 draw_team2 = draw['Away Team Name'].value_counts().sort_values(ascending = False).to_frame().reset_index().rename(columns={'Away Team Name':'Draw','index':'Team'})
# ----> 4 draw_team = pd.merge(draw_team1,draw_team2,on='Team',how='outer').fillna(0)
#       5 draw_team["Draw"] = draw_team['Draw_x'] + draw_team['Draw_y']
# ...
